# %%
import yfinance as yf   

ticker = yf.Ticker("AAPL")
df = ticker.history(period="10y")

# Save to CSV
df.to_csv("AAPL_10y.csv")

print("CSV file saved successfully")
# Out:
# CSV file saved successfully
